# %% [markdown]
# ## Basic Exploration of the 256 kHz Pacific Ocean Audio Data in the AWS Open Data Registry
#
# ---
# An extensive (5+ years and growing) archive of sound recordings from a deep-sea location [along the eastern margin of the North Pacific Ocean](https://www.mbari.org/at-sea/cabled-observatory/) has been made available through AWS Open data.  Temporal coverage of the recording archive has been 95% since project inception in July 2015.  The original recordings have a sample rate of 256 kHz.  This notebook illustrates basic methods to access and process the original audio data using Python.
#
#
#  <div style="text-align: center">
#  <h3>A delayed version of this data can be heard here on this live audio station</h3>
#  <audio controls>
#  <source src="http://listen.shoutcast.com/oceansoundscape" type="audio/mpeg">
#  Your browser does not support the audio player to play the live stream from Monterey Bay  </audio>
# </div>

# %% [markdown]
# ## Data Overview
# The full-resolution audio data are in [WAV](https://en.wikipedia.org/wiki/WAV) format in s3 buckets named <b>pacific-sound-256khz-yyyy</b>, where yyyy is 2015 or later.  Buckets are stored as objects, so the data aren't physically stored in folders or directories as you may be famaliar with, but you can think of it conceptually as follows:
#
# ```
# pacific-sound-256khz-2021
#       |
#       individual 10-minute files
# ```

# %% [markdown]
# ## Install required dependencies
#
# First, let's install the required software dependencies.

# %%
# !pip3 install -q boto3
# !pip3 install -q soundfile
# !pip3 install -q scipy
# !pip3 install -q numpy
# !pip3 install -q matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 69.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.1 MB/s eta 0:00:00

# %% [markdown]
# ### Import all packages

# %%
import boto3
from botocore import UNSIGNED
from botocore.client import Config
from six.moves.urllib.request import urlopen
import io
import scipy
from scipy import signal, interpolate
import numpy as np
import soundfile as sf
import matplotlib.pyplot as plt
from sys import prefix
import datetime
import os
import logging as log
import sys
from logging import StreamHandler

# %% [markdown]
# ## List the contents of a monthly directory
# ### The recordings are a uploaded in the AWS S3. We use the boto3 to download the files. Since the files are open for public use the id and secret key are not required so the they are left blank.

# %%
s3 = boto3.client('s3',
    aws_access_key_id='',
    aws_secret_access_key='',
    config=Config(signature_version=UNSIGNED))

# %% [markdown]
# ### In the below box we can adding all the files for the given years in a list. The. files are present in S3 under a bucket and it is given below. You will can select the months in other code block do not change the values for month in the for loop. The hydrophone uploads 6 files for an hour ie each file for 10 minutes.

# %%
year_to_process=2022

#start of month


bucket = f'pacific-sound-256khz-{year_to_process}'


paginator = s3.get_paginator('list_objects_v2')
day_obj_keys = []

for month in range(1,13):
    prefix_day = f'{month:02d}/MARS_{year_to_process}{month:02d}'

    pages = paginator.paginate(Bucket=bucket, Prefix=prefix_day)
    for page in pages:
        if 'Contents' in page:
            for obj in page['Contents']:
                # print(obj['Key'])
                day_obj_keys.append(obj['Key'])
# Out:
# 50602

# %% [markdown]
# ## Handling missing files
# ### Each year is supposed to have around 52560 file but many files can be missing so we need to replace the missing days with NaN. This is done in the below code. Here we will create the fake file names for an year and match them with the actual filesname and will the print statements will provide the required information like number of missing files and so on.

# %%
total_count = 0 # This will now represent total expected 10-min slots
n_count = 0     # Missing files (NaNs)
file_count = 0  # Matched files

# total_nums_days is not strictly needed for the matching logic but can be kept for debug print if desired
total_nums_days = 0
monthly_file_keys = []
actual_key_index = 0 # Pointer for the sorted parsed_day_obj_keys

minutes_to_add = 10


parsed_day_obj_keys = []
for key in day_obj_keys:
    try:
        # key format: 'MM/MARS_YYYYMMDD_HHMM
        month_val = int(key[0:2])
        year_val = int(key[8:12])
        day_val = int(key[14:16])
        hour_val = int(key[17:19])
        minute_val = int(key[19:21])

        file_dt = datetime.datetime(year_val, month_val, day_val, hour_val, minute_val)
        parsed_day_obj_keys.append((file_dt, key))
    except (ValueError, IndexError) as e:
        print(f"Warning: Could not parse key '{key}'. Skipping. Error: {e}")
        continue

# Sort the parsed keys by their datetime objects.
parsed_day_obj_keys.sort()


for month in range(1, 13):
  current_date = datetime.datetime(year_to_process, month, 1)

  if month == 12:
        next_month = datetime.datetime(year_to_process + 1, 1, 1)
  else:
        next_month = datetime.datetime(year_to_process, month + 1, 1)

  num_month_days = (next_month - current_date).days
  total_nums_days += num_month_days # Kept for consistency if you use it elsewhere

  for day in range(1, num_month_days + 1):
    for hour in range(0, 24):

      # start_time for the *current hour* (e.g., 2020-01-01 10:00:00)
      start_time = datetime.datetime(year=year_to_process, month=month, day=day, hour=hour, minute=0)

      for chunk_ind in range(0, 6): # Iterate through 6 ten-minute chunks in an hour

        # Calculate the precise start and end time for the current 10-minute slot
        current_slot_start_time = start_time + datetime.timedelta(minutes=chunk_ind * minutes_to_add)
        current_slot_end_time = current_slot_start_time + datetime.timedelta(minutes=minutes_to_add)

        total_count += 1 # Increment total expected slots

        matched_for_this_slot = False

        # find a matching file key from the sorted list
        # This while loop only advances actual_key_index forward
        while actual_key_index < len(parsed_day_obj_keys):
            file_dt, original_key_string = parsed_day_obj_keys[actual_key_index]

            # If the file's timestamp is before the current slot,
            # it means this file was either already processed or is simply too old for this slot.
            # Move to the next file in `parsed_day_obj_keys`.
            if file_dt < current_slot_start_time:
                actual_key_index += 1
                continue # Check the next file key

            # If the file's timestamp falls within the current 10-minute slot:
            # (Using [start, end) interval, typical for time series)
            if current_slot_start_time <= file_dt < current_slot_end_time:
                monthly_file_keys.append(original_key_string)
                file_count += 1
                actual_key_index += 1 # Move to the next file key, as this one has been matched
                matched_for_this_slot = True
                break # Found a match for this slot, stop checking keys for THIS slot

            # If the file's timestamp is after the current slot,
            # then no subsequent files in `parsed_day_obj_keys` (because it's sorted)
            # will match the current slot. So, we stop looking for this slot.
            if file_dt >= current_slot_end_time:
                break # No match for this slot, and current file is too new.

        # If after checking relevant keys, no match was found for the current 10-minute slot
        if not matched_for_this_slot:
            monthly_file_keys.append(np.nan)
            n_count += 1

# --- Final Print Statements ---

print(f'The number of keys present (original day_obj_keys): {len(day_obj_keys)} are present in the year : {year_to_process}')
print(f'Total expected 10-minute slots for the year {year_to_process}: {total_count}')
print(f'Actual number of keys matched: {file_count}')
print(f'Number of missing (NaN) slots: {n_count}')
print(f'The length of the list monthly_file_keys (should equal total_expected_slots): {len(monthly_file_keys)}')

# A consistency check
if file_count + n_count == total_count:
    print("Consistency check: matched files + missing slots = total expected slots. (OK)")
else:
    print("WARNING: Inconsistency detected! Counts do not add up correctly.")

# Check for any remaining unmatched keys in day_obj_keys
unmatched_original_keys = len(day_obj_keys) - file_count
if unmatched_original_keys > 0:
    print(f"Number of original day_obj_keys that were not matched to any slot: {unmatched_original_keys}")
    # To see which ones, you'd need to extract them from parsed_day_obj_keys[actual_key_index:]
# Out:
# The number of keys present (original day_obj_keys): 50602 are present in the year : 2022
# Total expected 10-minute slots for the year 2022: 52560
# Actual number of keys matched: 50595
# Number of missing (NaN) slots: 1965
# The length of the list monthly_file_keys (should equal total_expected_slots): 52560
# Consistency check: matched files + missing slots = total expected slots. (OK)
# Number of original day_obj_keys that were not matched to any slot: 7

# %% [markdown]
# ### All the blocks till this point need to be run only one time right at the starting. In the below block you can choose the range of day and month.
#
# ###month_start= here update the starting day
# ###mnth_strt_day= here mention the starting month
#
# ###end_month= here update the end day
# ###end_mnth_day= here update the end month

# %%
month_start=12
mnth_strt_day=21

#end of month
end_month=12
end_mnth_day=25

# %% [markdown]
# ##### Here happens the core processing processes. The current notebook is for pacific sound of 256khz. But we resample it to 48khz. Here we download the actaul files.
#
# ##### Resampling: The original audio data is resampled from the original sample rate (orig_sr) to the target sample rate (target_sr).
# ##### Welch PSD: Uses the scipy.signal.welch method to calculate the Power Spectral Density of each audio segment.
# ##### Calibration: Sensitivity calibration is applied to the computed PSD using factory calibration data (calfreq and calsens).
# ##### Data Storage: The results are stored in a .mat file, which is compatible with MATLAB. This includes the calibrated PSD values, frequency bins, and metadata.
#
# ##### More explantion about the variables are given on next text block.

# %%
# --- Configuration ---
target_sec = 3600  # 1 hour (3600 seconds)
target_sr = 48000
orig_sr = 256000


output_dir = 'calibrated_psds_yearly/'  # directory for monthly mat files
os.makedirs(output_dir, exist_ok=True)

# Factory calibration data (assuming this is constant)
calfreq = [0, 250, 10000, 20100, 30100, 40200, 50200, 60200, 70300, 80300, 90400, 100400, 110400, 120500, 130500, 140500, 150600, 160600, 170700, 180700, 190700, 200000]
calsens = [-177.90, -177.90, -176.80, -176.35, -177.05, -177.35, -177.30, -178.05, -178.00, -178.40, -178.85, -180.25, -180.50, -179.90, -180.15, -180.20, -180.75, -180.90, -181.45, -181.30, -180.75, -180.30]

f_welch_global = None
isens_truncated_global = None
target_bins = 20000  # band of interest




total_days_in_year = (datetime.date(year_to_process + 1, 1, 1) - datetime.date(year_to_process, 1, 1)).days
total_expected_chunks_in_year = total_days_in_year * 24 * 6

start_date_of_year = datetime.date(year_to_process, 1, 1) # This is the absolute start of monthly_file_keys
start_date_process = datetime.date(year_to_process, month_start, mnth_strt_day) # Start date for this processing run
end_date_process = datetime.date(year_to_process, end_month, end_mnth_day)   # End date for this processing run

current_date = start_date_process # Use this for iterating through days

# --- Second Code Block: Process monthly_file_keys ---
while current_date <= end_date_process:
    print(f"\n--- Processing Date: {current_date.strftime('%Y-%m-%d')} ---")

    absolute_day_number_from_year_start = (current_date - start_date_of_year).days
    day_start_index = absolute_day_number_from_year_start * 144 # 144 chunks per day
    day_end_index = day_start_index + 144

    # Ensure the slice doesn't go out of bounds of monthly_file_keys
    if day_start_index >= len(monthly_file_keys):
        print(f"    Warning: No more data in monthly_file_keys for {current_date.strftime('%Y-%m-%d')} (index {day_start_index}). All hours will be NaN.")
        daily_file_keys_slice = [] # Indicate no keys for this day
    else:
        daily_file_keys_slice = monthly_file_keys[day_start_index:day_end_index]

    hourly_groups_for_day = [daily_file_keys_slice[i:i + 6] for i in range(0, len(daily_file_keys_slice), 6)]

    daily_calibrated_psds = []

    for hour_idx, hour_group in enumerate(hourly_groups_for_day):
        audio_segments_for_hour = [] # This list will hold valid audio arrays
        total_sec_current_hour = 0
        temp_sg_db_columns = []

        print(f"\n  Processing hour group {hour_idx:02d} for {current_date.strftime('%Y-%m-%d')}")

        for key in hour_group:

            if not isinstance(key, str):
                continue
            url = f'https://{bucket}.s3.amazonaws.com/{key}'
            try:
                with urlopen(url) as response:
                    audio_data = response.read()
                x, sr = sf.read(io.BytesIO(audio_data), dtype='float32')

                if sr != orig_sr:
                    print(f"    Warning: Expected {orig_sr} Hz sample rate for {key} but got {sr}. Skipping.")
                    continue
                  # now we have the original sample rate at 'x' and the corresponding scaled voltage values

                new_num_samples = int(len(x) * target_sr / orig_sr)
                v1 = signal.resample(x * 3, new_num_samples)
                v = np.array(v1)

                #since we need to downsample the signal we find the new number of line from the formula given above
                # then we use the resample funtion to produce the new required voltage signals and also by multiplying with 3 we convert the
                #scaled voltage to volts
                #then it is converted to array

                dur = len(v) / target_sr
                total_sec_current_hour += dur
                audio_segments_for_hour.append(v)

                print(f'{key} | duration (s): {dur:.2f} | total_sec so far (this hour): {total_sec_current_hour:.2f}')

                if total_sec_current_hour >= target_sec:
                    break

            except Exception as e:
                print(f"Error processing {key}: {e}. Skipping this file.")
                continue


        if audio_segments_for_hour:
            concatenated_hour_data = np.concatenate(audio_segments_for_hour)

            if concatenated_hour_data.size > 0:
                sample_rate = target_sr
                spa = 3600
                nsec = concatenated_hour_data.size / sample_rate
                nseg = int(nsec / spa)

                if nseg == 0:
                    print(f"    Hour group {hour_idx:02d} has less than {spa} seconds of data. Appending NaN.")
                    daily_calibrated_psds.append(np.full((target_bins,), np.nan))
                    continue

                # nfreq = int(sample_rate / 2 + 1)

                nfft_welch = sample_rate
                nperseg_welch = 2048
                # nperseg_welch = nseg
                noverlap_welch = nperseg_welch // 2 # Fixed to 50% overlap

                segment_length_samples = spa * sample_rate

                for i in range(nseg):
                    start_sample = int(i * segment_length_samples)
                    end_sample = int(start_sample + segment_length_samples)
                    segment = concatenated_hour_data[start_sample:end_sample]

                    current_nperseg = nperseg_welch
                    current_noverlap = noverlap_welch

                    if len(segment) < nperseg_welch:
                        current_nperseg = len(segment)
                        current_noverlap = current_nperseg // 2

                    if current_nperseg < 1:
                        print(f"Warning: Segment {i} in hour group {hour_idx:02d} is too short ({len(segment)} samples). Skipping.")
                        continue

                    f, Pxx = signal.welch(segment, fs=sample_rate, window='hann', nperseg=target_sr, noverlap=target_sr // 2, nfft=nfft_welch)

                    if f_welch_global is None:
                        f_welch_global = f
                        tck = interpolate.splrep(calfreq, calsens, s=0)
                        isens_global = interpolate.splev(f_welch_global, tck, der=0)

                        if f_welch_global.size >= target_bins:
                            isens_truncated_global = isens_global[:target_bins]
                        else:
                            print(f"Warning: f_welch has fewer than {target_bins} bins ({f_welch_global.size}). Calibration will use available bins.")
                            target_bins = f_welch_global.size # Adjust target_bins here
                            isens_truncated_global = isens_global

                    # Always append if Pxx is a valid array of the expected size for the first time or consistent size
                    # Better to check if Pxx is valid rather than specific size match unless strictly required
                    if Pxx.size > 0: # Ensure Pxx is not empty
                        temp_sg_db_columns.append(10 * np.log10(Pxx))
                    else:
                        print(f"Warning: Pxx is empty for segment {i} in hour {hour_idx:02d}. Skipping.")
                        continue

            if len(temp_sg_db_columns) >= 1:
                sg_hour = np.stack(temp_sg_db_columns, axis=1)
                mean_psd_db_hour = np.mean(sg_hour, axis=1)

                print(f"    Successfully computed mean PSD for hour group {hour_idx:02d}")

                if f_welch_global is not None and isens_truncated_global is not None:
                    # Ensure mean_psd_db_hour and isens_truncated_global have compatible shapes
                    if mean_psd_db_hour.shape[0] < target_bins:
                        print(f"    Warning: Hourly PSD has fewer bins than target_bins ({mean_psd_db_hour.shape[0]} vs {target_bins}). Using available bins.")
                        current_mean_psd_db_hour = mean_psd_db_hour
                    else:
                        current_mean_psd_db_hour = mean_psd_db_hour[:target_bins]

                    if isens_truncated_global.shape[0] != current_mean_psd_db_hour.shape[0]:
                        isens_truncated_global_adjusted = isens_truncated_global[:current_mean_psd_db_hour.shape[0]]
                        print(f"    Adjusting isens_truncated_global size from {isens_truncated_global.shape[0]} to {isens_truncated_global_adjusted.shape[0]}.")
                    else:
                        isens_truncated_global_adjusted = isens_truncated_global

                    sg_calibrated = current_mean_psd_db_hour - isens_truncated_global_adjusted
                    daily_calibrated_psds.append(sg_calibrated)
                else:
                    print(f"    Calibration data (f_welch_global or isens_truncated_global) not ready for hour {hour_idx:02d}. Appending NaN vector.")
                    daily_calibrated_psds.append(np.full((target_bins,), np.nan))
            else:
                print(f"    No valid segments could be processed into PSDs for hour group {hour_idx:02d}. Appending NaN vector.")
                daily_calibrated_psds.append(np.full((target_bins,), np.nan))
        else: # This handles cases where concatenated_hour_data is empty
            print(f"    Concatenated hour data is empty for hour {hour_idx:02d}. Appending NaN.")
            daily_calibrated_psds.append(np.full((target_bins,), np.nan))

    # Ensure we have 24 hours (fill with NaN if not)
    while len(daily_calibrated_psds) < 24:
        daily_calibrated_psds.append(np.full((target_bins,), np.nan))

    daily_calibrated_psds_array = np.array(daily_calibrated_psds)

    filename = os.path.join(output_dir, f'calibrated_psd_{current_date.strftime("%Y%m%d")}.mat')


    daily_calibrated_psds_array_for_mat = daily_calibrated_psds_array.T


    mat_data = {
        'calibrated_hourly_PSD_dB': daily_calibrated_psds_array_for_mat,
        'description': (
            "Calibrated hourly Power Spectral Density. "
            f"Matrix columns represent hours (0-23) for {current_date.strftime('%Y-%m-%d')}. "
            "Values are in dB re 1 uPa^2/Hz. "
            "NaNs indicate missing or invalid data for an hour."
        ),
        'frequencies_Hz': f_welch_global[:target_bins] if f_welch_global is not None else np.arange(target_bins),
        'sample_rate_Hz': target_sr,
        'spa_seconds': spa
    }

    scipy.io.savemat(filename, mat_data)
    print(f"--- Saved calibrated PSDs for {current_date.strftime('%Y-%m-%d')} to {filename} ---")

    # Move to the next day
    current_date += datetime.timedelta(days=1)

print("Processing complete.")
# Out:
# --- Processing Date: 2022-12-21 ---
#
#   Processing hour group 00 for 2022-12-21
# 12/MARS_20221221_000208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_001208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_002208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_003208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_004208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_005208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 00
#
#   Processing hour group 01 for 2022-12-21
# 12/MARS_20221221_010208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_011208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_012208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_013208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_014208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_015208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 01
#
#   Processing hour group 02 for 2022-12-21
# 12/MARS_20221221_020208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_021208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_022208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_023208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_024208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_025208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 02
#
#   Processing hour group 03 for 2022-12-21
# 12/MARS_20221221_030208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_031208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_032208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_033208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_034208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_035208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 03
#
#   Processing hour group 04 for 2022-12-21
# 12/MARS_20221221_040208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_041208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_042208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_043208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_044208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_045208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 04
#
#   Processing hour group 05 for 2022-12-21
# 12/MARS_20221221_050208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_051208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_052208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_053208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_054208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_055208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 05
#
#   Processing hour group 06 for 2022-12-21
# 12/MARS_20221221_060208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_061208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_062208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_063208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_064208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_065208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 06
#
#   Processing hour group 07 for 2022-12-21
# 12/MARS_20221221_070208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_071208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_072208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_073208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_074208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_075208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 07
#
#   Processing hour group 08 for 2022-12-21
# 12/MARS_20221221_080208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_081208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_082208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_083208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_084208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_085208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 08
#
#   Processing hour group 09 for 2022-12-21
# 12/MARS_20221221_090208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_091208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_092208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_093208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_094208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_095208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 09
#
#   Processing hour group 10 for 2022-12-21
# 12/MARS_20221221_100208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_101208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_102208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_103208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_104208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_105208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 10
#
#   Processing hour group 11 for 2022-12-21
# 12/MARS_20221221_110208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_111208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_112208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_113208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_114208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_115208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 11
#
#   Processing hour group 12 for 2022-12-21
# 12/MARS_20221221_120208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_121208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_122208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_123208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_124208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_125208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 12
#
#   Processing hour group 13 for 2022-12-21
# 12/MARS_20221221_130208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_131208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_132208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_133208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_134208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_135208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 13
#
#   Processing hour group 14 for 2022-12-21
# 12/MARS_20221221_140208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_141208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_142208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_143208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_144208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_145208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 14
#
#   Processing hour group 15 for 2022-12-21
# 12/MARS_20221221_150208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_151208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_152208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_153208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_154208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_155208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 15
#
#   Processing hour group 16 for 2022-12-21
# 12/MARS_20221221_160208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_161208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_162208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_163208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_164208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_165208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 16
#
#   Processing hour group 17 for 2022-12-21
# 12/MARS_20221221_170208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_171208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_172208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_173208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_174208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_175208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 17
#
#   Processing hour group 18 for 2022-12-21
# 12/MARS_20221221_180208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_181208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_182208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_183208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_184208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_185208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 18
#
#   Processing hour group 19 for 2022-12-21
# 12/MARS_20221221_190208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_191208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_192208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_193208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_194208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_195208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 19
#
#   Processing hour group 20 for 2022-12-21
# 12/MARS_20221221_200208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_201208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_202208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_203208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_204208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_205208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 20
#
#   Processing hour group 21 for 2022-12-21
# 12/MARS_20221221_210208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_211208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_212208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_213208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_214208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_215208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 21
#
#   Processing hour group 22 for 2022-12-21
# 12/MARS_20221221_220208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_221208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_222208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_223208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_224208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_225208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 22
#
#   Processing hour group 23 for 2022-12-21
# 12/MARS_20221221_230208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221221_231208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221221_232208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221221_233208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221221_234208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221221_235208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 23
# --- Saved calibrated PSDs for 2022-12-21 to calibrated_psds_yearly/calibrated_psd_20221221.mat ---
#
# --- Processing Date: 2022-12-22 ---
#
#   Processing hour group 00 for 2022-12-22
# 12/MARS_20221222_000208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_001208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_002208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_003208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_004208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_005208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 00
#
#   Processing hour group 01 for 2022-12-22
# 12/MARS_20221222_010208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_011208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_012208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_013208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_014208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_015208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 01
#
#   Processing hour group 02 for 2022-12-22
# 12/MARS_20221222_020208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_021208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_022208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_023208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_024208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_025208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 02
#
#   Processing hour group 03 for 2022-12-22
# 12/MARS_20221222_030208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_031208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_032208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_033208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_034208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_035208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 03
#
#   Processing hour group 04 for 2022-12-22
# 12/MARS_20221222_040208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_041208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_042208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_043208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_044208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_045208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 04
#
#   Processing hour group 05 for 2022-12-22
# 12/MARS_20221222_050208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_051208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_052208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_053208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_054208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_055208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 05
#
#   Processing hour group 06 for 2022-12-22
# 12/MARS_20221222_060208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_061208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_062208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_063208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_064208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_065208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 06
#
#   Processing hour group 07 for 2022-12-22
# 12/MARS_20221222_070208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_071208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_072208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_073208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_074208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_075208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 07
#
#   Processing hour group 08 for 2022-12-22
# 12/MARS_20221222_080208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_081208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_082208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_083208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_084208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_085208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 08
#
#   Processing hour group 09 for 2022-12-22
# 12/MARS_20221222_090208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_091208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_092208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_093208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_094208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_095208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 09
#
#   Processing hour group 10 for 2022-12-22
# 12/MARS_20221222_100208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_101208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_102208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_103208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_104208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_105208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 10
#
#   Processing hour group 11 for 2022-12-22
# 12/MARS_20221222_110208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_111208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_112208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_113208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_114208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_115208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 11
#
#   Processing hour group 12 for 2022-12-22
# 12/MARS_20221222_120208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_121208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_122208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_123208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_124208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_125208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 12
#
#   Processing hour group 13 for 2022-12-22
# 12/MARS_20221222_130208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_131208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_132208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_133208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_134208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_135208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 13
#
#   Processing hour group 14 for 2022-12-22
# 12/MARS_20221222_140208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_141208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_142208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_143208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_144208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_145208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 14
#
#   Processing hour group 15 for 2022-12-22
# 12/MARS_20221222_150208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_151208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_152208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_153208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_154208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_155208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 15
#
#   Processing hour group 16 for 2022-12-22
# 12/MARS_20221222_160208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_161208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_162208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_163208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_164208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_165208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 16
#
#   Processing hour group 17 for 2022-12-22
# 12/MARS_20221222_170208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_171208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_172208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_173208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_174208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_175208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 17
#
#   Processing hour group 18 for 2022-12-22
# 12/MARS_20221222_180208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_181208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_182208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_183208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_184208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_185208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 18
#
#   Processing hour group 19 for 2022-12-22
# 12/MARS_20221222_190208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_191208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_192208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_193208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_194208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_195208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 19
#
#   Processing hour group 20 for 2022-12-22
# 12/MARS_20221222_200208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_201208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_202208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_203208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_204208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_205208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 20
#
#   Processing hour group 21 for 2022-12-22
# 12/MARS_20221222_210208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_211208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_212208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_213208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_214208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_215208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 21
#
#   Processing hour group 22 for 2022-12-22
# 12/MARS_20221222_220208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_221208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_222208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_223208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_224208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_225208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 22
#
#   Processing hour group 23 for 2022-12-22
# 12/MARS_20221222_230208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221222_231208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221222_232208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221222_233208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221222_234208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221222_235208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 23
# --- Saved calibrated PSDs for 2022-12-22 to calibrated_psds_yearly/calibrated_psd_20221222.mat ---
#
# --- Processing Date: 2022-12-23 ---
#
#   Processing hour group 00 for 2022-12-23
# 12/MARS_20221223_000208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_001208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_002208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_003208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_004208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_005208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 00
#
#   Processing hour group 01 for 2022-12-23
# 12/MARS_20221223_010208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_011208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_012208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_013208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_014208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_015208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 01
#
#   Processing hour group 02 for 2022-12-23
# 12/MARS_20221223_020208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_021208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_022208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_023208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_024208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_025208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 02
#
#   Processing hour group 03 for 2022-12-23
# 12/MARS_20221223_030208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_031208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_032208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_033208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_034208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_035208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 03
#
#   Processing hour group 04 for 2022-12-23
# 12/MARS_20221223_040208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_041208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_042208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_043208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_044208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_045208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 04
#
#   Processing hour group 05 for 2022-12-23
# 12/MARS_20221223_050208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_051208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_052208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_053208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_054208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_055208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 05
#
#   Processing hour group 06 for 2022-12-23
# 12/MARS_20221223_060208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_061208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_062208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_063208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_064208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_065208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 06
#
#   Processing hour group 07 for 2022-12-23
# 12/MARS_20221223_070208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_071208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_072208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_073208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_074208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_075208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 07
#
#   Processing hour group 08 for 2022-12-23
# 12/MARS_20221223_080208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_081208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_082208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_083208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_084208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_085208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 08
#
#   Processing hour group 09 for 2022-12-23
# 12/MARS_20221223_090208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_091208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_092208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_093208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_094208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_095208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 09
#
#   Processing hour group 10 for 2022-12-23
# 12/MARS_20221223_100208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_101208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_102208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_103208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_104208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_105208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 10
#
#   Processing hour group 11 for 2022-12-23
# 12/MARS_20221223_110208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_111208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_112208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_113208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_114208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_115208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 11
#
#   Processing hour group 12 for 2022-12-23
# 12/MARS_20221223_120208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_121208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_122208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_123208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_124208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_125208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 12
#
#   Processing hour group 13 for 2022-12-23
# 12/MARS_20221223_130208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_131208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_132208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_133208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_134208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_135208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 13
#
#   Processing hour group 14 for 2022-12-23
# 12/MARS_20221223_140208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_141208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_142208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_143208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_144208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_145208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 14
#
#   Processing hour group 15 for 2022-12-23
# 12/MARS_20221223_150208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_151208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_152208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_153208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_154208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_155208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 15
#
#   Processing hour group 16 for 2022-12-23
# 12/MARS_20221223_160208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_161208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_162208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_163208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_164208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_165208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 16
#
#   Processing hour group 17 for 2022-12-23
# 12/MARS_20221223_170208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_171208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_172208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_173208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_174208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_175208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 17
#
#   Processing hour group 18 for 2022-12-23
# 12/MARS_20221223_180208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_181208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_182208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_183208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_184208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_185208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 18
#
#   Processing hour group 19 for 2022-12-23
# 12/MARS_20221223_190208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_191208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_192208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_193208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_194208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_195208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 19
#
#   Processing hour group 20 for 2022-12-23
# 12/MARS_20221223_200208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_201208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_202208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_203208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_204208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_205208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 20
#
#   Processing hour group 21 for 2022-12-23
# 12/MARS_20221223_210208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_211208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_212208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_213208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_214208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_215208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 21
#
#   Processing hour group 22 for 2022-12-23
# 12/MARS_20221223_220208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_221208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_222208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_223208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_224208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_225208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 22
#
#   Processing hour group 23 for 2022-12-23
# 12/MARS_20221223_230208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221223_231208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221223_232208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221223_233208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221223_234208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221223_235208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 23
# --- Saved calibrated PSDs for 2022-12-23 to calibrated_psds_yearly/calibrated_psd_20221223.mat ---
#
# --- Processing Date: 2022-12-24 ---
#
#   Processing hour group 00 for 2022-12-24
# 12/MARS_20221224_000208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221224_001208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221224_002208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221224_003208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221224_004208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221224_005208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 00
#
#   Processing hour group 01 for 2022-12-24
# 12/MARS_20221224_010208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221224_011208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221224_012208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221224_013208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221224_014208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221224_015208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 01
#
#   Processing hour group 02 for 2022-12-24
# ...
# 12/MARS_20221224_233208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221224_234208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221224_235208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 23
# --- Saved calibrated PSDs for 2022-12-24 to calibrated_psds_yearly/calibrated_psd_20221224.mat ---
#
# --- Processing Date: 2022-12-25 ---
#
#   Processing hour group 00 for 2022-12-25
# 12/MARS_20221225_000208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_001208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_002208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_003208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_004208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_005208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 00
#
#   Processing hour group 01 for 2022-12-25
# 12/MARS_20221225_010208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_011208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_012208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_013208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_014208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_015208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 01
#
#   Processing hour group 02 for 2022-12-25
# 12/MARS_20221225_020208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_021208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_022208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_023208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_024208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_025208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 02
#
#   Processing hour group 03 for 2022-12-25
# 12/MARS_20221225_030208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_031208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_032208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_033208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_034208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_035208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 03
#
#   Processing hour group 04 for 2022-12-25
# 12/MARS_20221225_040208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_041208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_042208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_043208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_044208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_045208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 04
#
#   Processing hour group 05 for 2022-12-25
# 12/MARS_20221225_050208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_051208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_052208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_053208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_054208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_055208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 05
#
#   Processing hour group 06 for 2022-12-25
# 12/MARS_20221225_060208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_061208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_062208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_063208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_064208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_065208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 06
#
#   Processing hour group 07 for 2022-12-25
# 12/MARS_20221225_070208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_071208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_072208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_073208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_074208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_075208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 07
#
#   Processing hour group 08 for 2022-12-25
# 12/MARS_20221225_080208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_081208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_082208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_083208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_084208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_085208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 08
#
#   Processing hour group 09 for 2022-12-25
# 12/MARS_20221225_090208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_091208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_092208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_093208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_094208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_095208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 09
#
#   Processing hour group 10 for 2022-12-25
# 12/MARS_20221225_100208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_101208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_102208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_103208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_104208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_105208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 10
#
#   Processing hour group 11 for 2022-12-25
# 12/MARS_20221225_110208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_111208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_112208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_113208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_114208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_115208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 11
#
#   Processing hour group 12 for 2022-12-25
# 12/MARS_20221225_120208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_121208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_122208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_123208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_124208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_125208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 12
#
#   Processing hour group 13 for 2022-12-25
# 12/MARS_20221225_130208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_131208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_132208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_133208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_134208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_135208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 13
#
#   Processing hour group 14 for 2022-12-25
# 12/MARS_20221225_140208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_141208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_142208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_143208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_144208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_145208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 14
#
#   Processing hour group 15 for 2022-12-25
# 12/MARS_20221225_150208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_151208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_152208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_153208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_154208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_155208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 15
#
#   Processing hour group 16 for 2022-12-25
# 12/MARS_20221225_160208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_161208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_162208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_163208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_164208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_165208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 16
#
#   Processing hour group 17 for 2022-12-25
# 12/MARS_20221225_170208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_171208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_172208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_173208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_174208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_175208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 17
#
#   Processing hour group 18 for 2022-12-25
# 12/MARS_20221225_180208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_181208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_182208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_183208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_184208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_185208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 18
#
#   Processing hour group 19 for 2022-12-25
# 12/MARS_20221225_190208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_191208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_192208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_193208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_194208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_195208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 19
#
#   Processing hour group 20 for 2022-12-25
# 12/MARS_20221225_200208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_201208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_202208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_203208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_204208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_205208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 20
#
#   Processing hour group 21 for 2022-12-25
# 12/MARS_20221225_210208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_211208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_212208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_213208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_214208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_215208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 21
#
#   Processing hour group 22 for 2022-12-25
# 12/MARS_20221225_220208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_221208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_222208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_223208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_224208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_225208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 22
#
#   Processing hour group 23 for 2022-12-25
# 12/MARS_20221225_230208.wav | duration (s): 600.00 | total_sec so far (this hour): 600.00
# 12/MARS_20221225_231208.wav | duration (s): 600.00 | total_sec so far (this hour): 1200.00
# 12/MARS_20221225_232208.wav | duration (s): 600.00 | total_sec so far (this hour): 1800.00
# 12/MARS_20221225_233208.wav | duration (s): 600.00 | total_sec so far (this hour): 2400.00
# 12/MARS_20221225_234208.wav | duration (s): 600.00 | total_sec so far (this hour): 3000.00
# 12/MARS_20221225_235208.wav | duration (s): 600.00 | total_sec so far (this hour): 3600.00
#     Successfully computed mean PSD for hour group 23
# --- Saved calibrated PSDs for 2022-12-25 to calibrated_psds_yearly/calibrated_psd_20221225.mat ---
# Processing complete.

# %% [markdown]
# ##### target_sec: The target number of seconds (3600 seconds = 1 hour). This value is used to ensure that each processed hour has a duration of 1 hour.
# ##### target_sr: The target sample rate (48,000 Hz). The audio data is resampled to this rate.
# ##### orig_sr: The original sample rate (256,000 Hz). The script checks if the audio data matches this rate.
# ##### output_dir: Directory to save the calibrated PSD files.
# ##### calfreq and calsens: Factory calibration frequency points and corresponding sensitivities (in dB).
# ##### f_welch_global: Placeholder for the frequency array from the Welch PSD calculation.
# ##### isens_truncated_global: Placeholder for the truncated sensitivity calibration data.
# ##### target_bins: The number of frequency bins to use in the PSD output (set to 20,000).
# ##### Date Range Configuration:
# ##### total_days_in_year: The total number of days in the year to process.
# ##### total_expected_chunks_in_year: The expected number of chunks based on 24 hours per day and 6 chunks per hour.
# ##### start_date_of_year: Start date of the year for reference.
# ##### start_date_process: The actual start date for processing data.
# ##### end_date_process: The actual end date for processing data.
